# %%
import numpy as np
import sqlite3
from datetime import datetime
con = sqlite3.connect('LDP_minimax.db')
cursor_db = con.cursor()

# %%
data = np.load("/Users/jmmoon/Documents/GitHub/LDPUts/experiment/power_ptbunif_k1000/result/k1000_priv20_methodgenrrchi_n380000.npy")

# %%
time_now = datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')
k=1000
priv=2
mechanism = "genrr"
statistic = "chi"
sample_size = 380000
bump = 0.0009

for i in range(200):
    p_val_now = data[i,0]
    print(p_val_now)
    data_entry = (i+1, k, bump, priv, sample_size, statistic, mechanism, p_val_now, time_now)
    cursor_db.execute(
        "INSERT INTO ldp_disc_basic_comparison(rep, dim, bump, priv_lev, sample_size, statistic, mechanism, p_val, jobdate) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)", data_entry,
    )
con.commit()
con.close()
# Out:
# 0.8380000591278076
# 0.8740000128746033
# 0.014000000432133675
# 0.6170000433921814
# 0.7080000042915344
# 0.2590000033378601
# 0.03500000014901161
# 0.11000000685453415
# 0.18400001525878906
# 0.581000030040741
# 0.07800000160932541
# 0.16200000047683716
# 0.33400002121925354
# 0.01900000125169754
# 0.2750000059604645
# 0.164000004529953
# 0.3880000114440918
# 0.7710000276565552
# 0.675000011920929
# 0.24900001287460327
# 0.049000002443790436
# 0.3500000238418579
# 0.909000039100647
# 0.026000000536441803
# 0.15300001204013824
# 0.023000001907348633
# 0.9390000700950623
# 0.14300000667572021
# 0.5250000357627869
# 0.027000000700354576
# 0.21900001168251038
# 0.7200000286102295
# 0.06700000166893005
# 0.32600000500679016
# 0.737000048160553
# 0.02200000174343586
# 0.1770000010728836
# 0.15700000524520874
# 0.01900000125169754
# 0.0990000069141388
# 0.5110000371932983
# 0.6650000214576721
# 0.06200000271201134
# 0.9610000252723694
# 0.024000000208616257
# 0.3500000238418579
# 0.30800002813339233
# 0.7540000081062317
# 0.7950000166893005
# 0.18800000846385956
# 0.04400000348687172
# 0.03500000014901161
# 0.1300000101327896
# 0.03400000184774399
# 0.4710000157356262
# 0.6990000605583191
# 0.9940000176429749
# 0.06400000303983688
# 0.43800002336502075
# 0.3140000104904175
# 0.6670000553131104
# 0.08800000697374344
# 0.8790000677108765
# 0.04700000211596489
# 0.5509999990463257
# 0.3330000042915344
# 0.4710000157356262
# 0.44700002670288086
# 0.2410000115633011
# 0.11800000816583633
# 0.05700000375509262
# 0.6000000238418579
# 0.43400001525878906
# 0.2939999997615814
# 0.41200003027915955
# 0.7640000581741333
# 0.3920000195503235
# 0.16300000250339508
# 0.9930000305175781
# 0.17400000989437103
# 0.31200000643730164
# 0.4130000174045563
# 0.08400000631809235
# 0.2680000066757202
# 0.014000000432133675
# 0.2330000102519989
# 0.07700000703334808
# 0.015000000596046448
# 0.7780000567436218
# 0.16600000858306885
# 0.7780000567436218
# 0.4090000092983246
# 0.18300001323223114
# 0.0950000062584877
# 0.367000013589859
# 0.3700000047683716
# 0.4090000092983246
# 0.7680000066757202
# 0.19600000977516174
# 0.2600000202655792
# 0.013000000268220901
# 0.28700000047683716
# 0.4310000240802765
# 0.7090000510215759
# 0.33100003004074097
# 0.7540000081062317
# 0.1420000046491623
# 0.4400000274181366
# 0.5570000410079956
# 0.8380000591278076
# 0.6540000438690186
# 0.7450000643730164
# 0.6540000438690186
# 0.08800000697374344
# 0.3880000114440918
# 0.30100002884864807
# 0.9070000648498535
# 0.009000000543892384
# 0.11400000751018524
# 0.026000000536441803
# 0.010000000707805157
# 0.5520000457763672
# 0.675000011920929
# 0.0950000062584877
# 0.9620000720024109
# 0.21800000965595245
# 0.3960000276565552
# 0.09100000560283661
# 0.13600000739097595
# 0.445000022649765
# 0.24500000476837158
# 0.01100000087171793
# 0.08300000429153442
# 0.8990000486373901
# 0.4910000264644623
# 0.11400000751018524
# 0.6610000133514404
# 0.06100000441074371
# 0.2880000174045563
# 0.027000000700354576
# 0.003000000026077032
# 0.5490000247955322
# 0.3960000276565552
# 0.07000000029802322
# 0.11300000548362732
# 0.07000000029802322
# 0.14900000393390656
# 0.017000000923871994
# 0.09000000357627869
# 0.34700000286102295
# 0.5890000462532043
# 0.013000000268220901
# 0.5840000510215759
# 0.0010000000474974513
# 0.5590000152587891
# 0.8330000638961792
# 0.4020000100135803
# 0.2290000170469284
# 0.47700002789497375
# 0.6330000162124634
# 0.628000020980835
# 0.34700000286102295
# 0.026000000536441803
# 0.5410000085830688
# 0.5360000133514404
# 0.242000013589859
# 0.2550000250339508
# 0.4310000240802765
# 0.31700000166893005
# 0.9810000658035278
# 0.675000011920929
# 0.06200000271201134
# 0.242000013589859
# 0.7590000629425049
# 0.30400002002716064
# 0.2930000126361847
# 0.6040000319480896
# 0.359000027179718
# 0.19300000369548798
# 0.018000001087784767
# 0.10500000417232513
# 0.18200001120567322
# 0.02200000174343586
# 0.024000000208616257
# 0.35100001096725464
# 0.058000002056360245
# 0.2900000214576721
# 0.4100000262260437
# 0.26500001549720764
# 0.15900000929832458
# 0.5
# 0.09700000286102295
# 0.26100000739097595
# 0.492000013589859
# 0.4710000157356262
# 0.7440000176429749
# 0.08300000429153442
# 0.5890000462532043
# 0.039000000804662704
# 0.01900000125169754
# /var/folders/w6/6r_601k96td7lw3ztsw07_8w0000gn/T/ipykernel_83104/587517609.py:1: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   time_now = datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')
