# %%
import numpy as np
with np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/power_law/k_500_n_500_alpha_01_type_1_powerlaw.npy') as data:
# Out:
#   File "<ipython-input-7-b3948e3d1746>", line 2
#     with np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/power_law/k_500_n_500_alpha_01_type_1_powerlaw.npy') as data:
#                                                                                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
k_500_n_500_powerlaw = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/power_law/k_500_n_500_alpha_01_type_1_powerlaw.npy')
k_500_n_1000_powerlaw = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/power_law/k_500_n_1000_alpha_01_type_1_powerlaw.npy')
k_500_n_1500_powerlaw = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/power_law/k_500_n_1500_alpha_01_type_1_powerlaw.npy')
k_500_n_500_unif = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif/k_500_n_500_alpha_01_type_1_unif.npy')
k_500_n_1000_unif = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif/k_500_n_1000_alpha_01_type_1_unif.npy')
k_500_n_1500_unif = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif/k_500_n_1500_alpha_01_type_1_unif.npy')
#
k_500_n_500_unifperturb = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif_perturbed/k_500_n_500_alpha_01_type_1_unifperturbed.npy')
k_500_n_1000_unifperturb = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif_perturbed/k_500_n_1000_alpha_01_type_1_unifperturbed.npy')
k_500_n_1500_unifperturb = np.load('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif_perturbed/k_500_n_1500_alpha_01_type_1_unifperturbed.npy')

# %%
import matplotlib.pyplot as plt

# %%
type_1_nominal = np.linspace(0,1,100)
type_1_real_powerlaw_ell2_n500 = np.zeros(100)
type_1_real_powerlaw_genrr_n500 = np.zeros(100)
type_1_real_powerlaw_bitflip_n500 = np.zeros(100)

type_1_real_powerlaw_ell2_n1000 = np.zeros(100)
type_1_real_powerlaw_genrr_n1000 = np.zeros(100)
type_1_real_powerlaw_bitflip_n1000 = np.zeros(100)

type_1_real_powerlaw_ell2_n1500 = np.zeros(100)
type_1_real_powerlaw_genrr_n1500 = np.zeros(100)
type_1_real_powerlaw_bitflip_n1500 = np.zeros(100)

for i, level in enumerate(type_1_nominal):
    type_1_real_powerlaw_ell2_n500[i] = ( k_500_n_500_powerlaw[:,0]<level).mean()
    type_1_real_powerlaw_genrr_n500[i] = ( k_500_n_500_powerlaw[:,1]<level).mean()
    type_1_real_powerlaw_bitflip_n500[i] = ( k_500_n_500_powerlaw[:,2]<level).mean()
    
    type_1_real_powerlaw_ell2_n1000[i] = ( k_500_n_1000_powerlaw[:,0]<level).mean()
    type_1_real_powerlaw_genrr_n1000[i] = ( k_500_n_1000_powerlaw[:,1]<level).mean()
    type_1_real_powerlaw_bitflip_n1000[i] = ( k_500_n_1000_powerlaw[:,2]<level).mean()
    
    type_1_real_powerlaw_ell2_n1500[i] = ( k_500_n_1500_powerlaw[:,0]<level).mean()
    type_1_real_powerlaw_genrr_n1500[i] = ( k_500_n_1500_powerlaw[:,1]<level).mean()
    type_1_real_powerlaw_bitflip_n1500[i] = ( k_500_n_1500_powerlaw[:,2]<level).mean()
plt.figure(figsize=(30, 10))
plt.subplot(1,3,1)
plt.plot(type_1_nominal, type_1_nominal)
plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1500)
plt.title("lapu+ ell2")

plt.subplot(1,3,2)
plt.plot(type_1_nominal, type_1_nominal)
plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1500)
plt.title("genrr+ chi-sq")

plt.subplot(1,3,3)
plt.plot(type_1_nominal, type_1_nominal)
plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1500)
plt.title("bitflip  + chi-sq-proj")
# Out:
# Text(0.5, 1.0, 'bitflip  + chi-sq-proj')

# %%
plt.figure(figsize=(30, 10))
plt.subplot(1,3,1)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n500)
plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1500)
plt.title("lapu+ ell2")

plt.subplot(1,3,2)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n500)
plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1500)
plt.title("genrr+ chi-sq")

plt.subplot(1,3,3)
plt.plot(type_1_nominal, type_1_nominal)
#lt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n500)
plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1500)
plt.title("bitflip  + chi-sq-proj")
# Out:
# Text(0.5, 1.0, 'bitflip  + chi-sq-proj')

# %%
plt.figure(figsize=(30, 10))
plt.subplot(1,3,1)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1000)
plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1500)
plt.title("lapu+ ell2")

plt.subplot(1,3,2)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1000)
plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1500)
plt.title("genrr+ chi-sq")

plt.subplot(1,3,3)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1000)
plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1500)
plt.title("bitflip  + chi-sq-proj")
# Out:
# Text(0.5, 1.0, 'bitflip  + chi-sq-proj')
